# %% [markdown]
# Testing Git

# %%
import pandas as pd
df = pd.read_csv("Email Data.csv")
df
# Out:
#     Sent Date                                       Subject Line   Category 1  \
# 0      1/4/17                   USFSCO SMMC January E-Newsletter  ENEWSLETTER
# 1      1/4/17                   USFSCO SMMC January E-Newsletter  ENEWSLETTER
# 2      1/4/17  Savvy Spending Challenge - SMMC's January Enew...  ENEWSLETTER
# 3      2/1/17  6+ Saving Challenges - SMMC's February E-newsl...  ENEWSLETTER
# 4      2/1/17  6+ Saving Challenges - SMMC's February E-newsl...  ENEWSLETTER
# ..        ...                                                ...          ...
# 336       NaN                                                NaN          NaN
# 337       NaN                                                NaN          NaN
# 338       NaN                                                NaN          NaN
# 339       NaN                                                NaN          NaN
# 340       NaN                                                NaN          NaN
#
# ...

# %%
new_df = df["Total Opens"] / df["Unique Opens"]
new_df
# Out:
# 0      2.045908
# 1      2.153846
# 2      1.490683
# 3      1.449024
# 4      1.545455
#          ...
# 336         NaN
# 337         NaN
# 338         NaN
# 339         NaN
# 340         NaN
# Length: 341, dtype: float64
